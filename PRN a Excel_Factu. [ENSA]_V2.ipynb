# %%
#SCRIPT
import os # Maneja los arcchivos de la PC
import pandas as pd # Maneja los archivos PRN
import xlwings as xw # Maneja y modifica archivos Excel con o sin macros.

def leer_prn_flexible(prn_file):
    """
    Lee un PRN detectando si la primera línea es un preámbulo tipo 'Units: ...'
    y probando distintos separadores y codificaciones.
    Devuelve (df, None) si ok o (None, 'mensaje de error') si falla.
    """
    # ¿Hay preámbulo en la primera línea no vacía?
    skiprows = 0
    try:
        with open(prn_file, 'r', encoding='utf-8', errors='ignore') as f:
            for line in f:
                if line.strip():  # primera línea no vacía
                    first = line.strip().lower().lstrip('"')
                    if first.startswith('units:'):
                        skiprows = 1
                    break
    except Exception:
        # si hay problemas leyendo como utf-8, igual seguimos a read_csv
        pass

    # Intentos de lectura (delimitador y codificación)
    intentos_sep = [
        dict(sep=None, engine='python'),   # inferencia automática
        dict(sep='\t', engine='python'),   # tab
        dict(sep=',', engine='python'),    # coma
        dict(sep=';', engine='python'),    # punto y coma
        dict(sep=r'\s+', engine='python'), # 1+ espacios
    ]
    intentos_enc = ['utf-8', 'utf-8-sig', 'latin-1']

    ultimo_error = None
    for enc in intentos_enc:
        for kw in intentos_sep:
            try:
                df = pd.read_csv(
                    prn_file,
                    header=0,
                    skiprows=skiprows,
                    encoding=enc,
                    on_bad_lines='skip',
                    **kw
                )
                # Limpieza básica de nombres de columnas
                df.columns = (
                    pd.Index(df.columns)
                    .astype(str)
                    .str.replace('\ufeff', '', regex=False)  # BOM
                    .str.strip()
                )

                # Si por error quedó una fila duplicando el header, elimínala
                if not df.empty:
                    cols = [str(c).strip().lower() for c in df.columns]
                    first_row = [str(x).strip().lower() for x in df.iloc[0].tolist()]
                    if cols == first_row:
                        df = df.iloc[1:].reset_index(drop=True)

                return df, None
            except Exception as e:
                ultimo_error = str(e)
                continue

    return None, f"No se pudo leer con separadores/codificaciones comunes. Último error: {ultimo_error}"

# =========================================
# CONFIGURACIÓN: SOLO MODIFICA 3 parámetros
# =========================================
# 1) Ruta al archivo Excel .xlsm con macros
xlsm_file = r"C:\Users\nasca\Desktop\Python Scripts\AUTOMATIZACIÓN PRN a EXCEL_FACTURACIÓN\Libres Ensa_09_2025.xlsm"
# 2) Carpeta donde se encuentran los archivos PRN
prn_folder = r"C:\Users\nasca\Desktop\Python Scripts\AUTOMATIZACIÓN PRN a EXCEL_FACTURACIÓN\PRNs a COPIAR"

# 3) Días que tiene el mes a procesar (p.ej. 31, 30, 29)
days_in_month = 30

# Cantidad de lecturas esperadas (96 registros por día)
expected_readings = days_in_month * 96

# =========================================
# FIN CONFIGURACIÓN
# =========================================

# Estructura para registrar problemas y mostrarlos en tabla al final
issues_list = [] #Cre una variable vacía para allí agregar issues 

# Inicia Excel (puedes poner visible=True si deseas depurar)
app = xw.App(visible=False)
wb = app.books.open(xlsm_file)

# Convierte las hojas en lista
all_sheets_list = list(wb.sheets)

# Omitir la primera hoja y las últimas 5
if len(all_sheets_list) <= 6:
    print("\n[ADVERTENCIA] El libro no tiene suficientes hojas para "
          "omitir la primera y las últimas 5.")
    sheets_to_process = []
else:
    sheets_to_process = all_sheets_list[1:-2]

for sheet in sheets_to_process:
    sheet_name = sheet.name
    print(f"\nProcesando hoja: '{sheet_name}'")

    # Leer el número de suministro desde la celda E2
    numero = sheet.range("E2").value
    if not numero:
        print(f"  - Celda E2 vacía. Se omite la hoja '{sheet_name}'.")
        issues_list.append({
            'Hoja': sheet_name,
            'Suministro': None,
            'Problema': 'E2 vacía (no se procesó)',
            'LecturasEncontradas': None,
            'LecturasEsperadas': expected_readings
        })
        continue

    # Convertir a string de 8 dígitos
    try:
        numero_str = str(int(numero)).zfill(8)
    except ValueError:
        print(f"  - Valor en E2 no es numérico válido: '{numero}'. Se omite.")
        issues_list.append({
            'Hoja': sheet_name,
            'Suministro': numero,
            'Problema': 'Valor E2 no numérico',
            'LecturasEncontradas': None,
            'LecturasEsperadas': expected_readings
        })
        continue

    # Construir ruta al PRN
    prn_file = os.path.join(prn_folder, f"{numero_str}.prn")
    if not os.path.exists(prn_file):
        print(f"  - No existe el archivo PRN: '{prn_file}'. Se omite.")
        issues_list.append({
            'Hoja': sheet_name,
            'Suministro': numero_str,
            'Problema': f"No se encontró {numero_str}.prn",
            'LecturasEncontradas': None,
            'LecturasEsperadas': expected_readings
        })
        continue

    # Leer el archivo PRN
    
    df_prn, read_err = leer_prn_flexible(prn_file)
    if read_err:
        print(f"   -Error al leer :c'{prn_file}': {read_err}")
        issues_list.append({
            'Hoja': sheet_name,
            'Suministro': numero_str,
            'Problema': f"Error lectura PRN: {read_err}",
            'LecturasEncontradas': None,
            'LecturasEsperadas': expected_readings
        })
        continue

    # Verificar número de filas
    total_filas = len(df_prn)
    if total_filas != expected_readings:
        print(f"  - Se esperaban {expected_readings} lecturas, hay {total_filas}. Se omite.")
        issues_list.append({
            'Hoja': sheet_name,
            'Suministro': numero_str,
            'Problema': 'Lecturas diferentes',
            'LecturasEncontradas': total_filas,
            'LecturasEsperadas': expected_readings
        })
        continue

    # Verificar columnas 'kWh-Del' y 'kVARh-Q1'
    if not {'kWh-Del', 'kVARh-Q1'}.issubset(df_prn.columns):
        print(f"  - Faltan columnas 'kWh-Del' o 'kVARh-Q1'. Se omite.")
        issues_list.append({
            'Hoja': sheet_name,
            'Suministro': numero_str,
            'Problema': "Faltan columnas 'kWh-Del' o 'kVARh-Q1'",
            'LecturasEncontradas': total_filas,
            'LecturasEsperadas': expected_readings
        })
        continue

    # Extraer listas
    kwh_del_values = df_prn['kWh-Del'].dropna().tolist()
    kvarh_q1_values = df_prn['kVARh-Q1'].dropna().tolist()

    if len(kwh_del_values) != len(kvarh_q1_values):
        print(f"  - 'kWh-Del' y 'kVARh-Q1' tienen longitudes distintas. Se omite.")
        issues_list.append({
            'Hoja': sheet_name,
            'Suministro': numero_str,
            'Problema': "Columnas kWh-Del y kVARh-Q1 con longitudes distintas",
            'LecturasEncontradas': len(df_prn),
            'LecturasEsperadas': expected_readings
        })
        continue

    # Si llega aquí, pasó todas las validaciones => Copiar datos a Excel
    print(f"  - Copiando datos en la hoja '{sheet_name}' (Suministro={numero_str}).")

    two_columns = [
        [kwh_del_values[i], kvarh_q1_values[i]]
        for i in range(len(kwh_del_values))
    ]
    start_row = 17
    start_col = 6  # Col F
    end_row = start_row + len(two_columns) - 1
    end_col = start_col + 1  # Col G

    sheet.range((start_row, start_col), (end_row, end_col)).value = two_columns
    print(f"    * Se copiaron {len(two_columns)} lecturas en columnas F y G.")

# Al finalizar, guardamos y cerramos
wb.save()
wb.close()
app.quit()
print(f"\nEl archivo Excel '{xlsm_file}' se ha actualizado.")

# ==================================================
# MOSTRAR RESUMEN DE ERRORES EN JUPYTER (SI EXISTEN)
# ==================================================
if issues_list:
    df_issues = pd.DataFrame(issues_list)
    print("\nResumen de problemas encontrados:")
    display(df_issues)  # En Jupyter, display() mostrará la tabla con formato
else:
    print("\nNo se encontraron problemas en los archivos procesados.")
# Out:
# Procesando hoja: 'Backus'
#   - Copiando datos en la hoja 'Backus' (Suministro=35707003).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'NICOLL '
#   - Copiando datos en la hoja 'NICOLL ' (Suministro=25820885).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CINEPLANET'
#   - Copiando datos en la hoja 'CINEPLANET' (Suministro=25812097).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Empresa CENCOSUD-MT '
#   - Copiando datos en la hoja 'Empresa CENCOSUD-MT ' (Suministro=26457805).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Empresa CENCOSUD-BT'
#   - Copiando datos en la hoja 'Empresa CENCOSUD-BT' (Suministro=35471447).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MALL 2'
#   - Copiando datos en la hoja 'MALL 2' (Suministro=25814814).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'REAL PLAZA-MALL 1'
#   - Copiando datos en la hoja 'REAL PLAZA-MALL 1' (Suministro=25814805).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'OESCHLE'
#   - Copiando datos en la hoja 'OESCHLE' (Suministro=35984916).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PROMART'
#   - Copiando datos en la hoja 'PROMART' (Suministro=35628625).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'RIPLEY'
#   - Copiando datos en la hoja 'RIPLEY' (Suministro=26302445).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SUPERMERCADOS PERUANOS S.A.'
#   - Copiando datos en la hoja 'SUPERMERCADOS PERUANOS S.A.' (Suministro=25884022).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SAGAFALABELLA'
#   - Copiando datos en la hoja 'SAGAFALABELLA' (Suministro=25812210).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SODIMAC_II'
#   - Copiando datos en la hoja 'SODIMAC_II' (Suministro=36462827).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SODIMAC_I'
#   - Copiando datos en la hoja 'SODIMAC_I' (Suministro=25886653).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MAKRO'
#   - Copiando datos en la hoja 'MAKRO' (Suministro=26444594).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'TOTTUS - VICENTE'
#   - Copiando datos en la hoja 'TOTTUS - VICENTE' (Suministro=25734796).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'TOTTUS - VRHDELAT'
#   - Copiando datos en la hoja 'TOTTUS - VRHDELAT' (Suministro=25888362).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'OPEN PLAZA'
#   - Copiando datos en la hoja 'OPEN PLAZA' (Suministro=25888353).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'COMOLSA'
#   - Copiando datos en la hoja 'COMOLSA' (Suministro=27512572).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'INDUAMERICA_25751474'
#   - Copiando datos en la hoja 'INDUAMERICA_25751474' (Suministro=25751474).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CERÁMICOS LAMBAYEQUE'
#   - Copiando datos en la hoja 'CERÁMICOS LAMBAYEQUE' (Suministro=25876773).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'AGRICOLA_CERRO_PRIETO'
#   - Copiando datos en la hoja 'AGRICOLA_CERRO_PRIETO' (Suministro=25829110).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'TROPICAL_I'
#   - Copiando datos en la hoja 'TROPICAL_I' (Suministro=25632938).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'TROPICAL_II'
#   - Copiando datos en la hoja 'TROPICAL_II' (Suministro=36385719).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOLINO LOS ANGELES'
#   - Copiando datos en la hoja 'MOLINO LOS ANGELES' (Suministro=27512699).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'TELEFONICA DEL PERU'
#   - Copiando datos en la hoja 'TELEFONICA DEL PERU' (Suministro=25595173).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOLINO_SAN_NICOLAS_27512554'
#   - Copiando datos en la hoja 'MOLINO_SAN_NICOLAS_27512554' (Suministro=27512554).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Mol_San Fernando'
#   - Se esperaban 2880 lecturas, hay 420. Se omite.
#
# Procesando hoja: 'AJEPER'
#   - Copiando datos en la hoja 'AJEPER' (Suministro=36439990).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PERALES HUANCARUNA S.A.C.'
#   - Copiando datos en la hoja 'PERALES HUANCARUNA S.A.C.' (Suministro=26248968).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'ENVASES SAN NICOLAS S.A.C'
#   - Copiando datos en la hoja 'ENVASES SAN NICOLAS S.A.C' (Suministro=37243010).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'NESSUS HOTELES PERU S.A.'
#   - Copiando datos en la hoja 'NESSUS HOTELES PERU S.A.' (Suministro=25597089).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOLINOS & CIA SEMPER S.A.C.'
#   - Copiando datos en la hoja 'MOLINOS & CIA SEMPER S.A.C.' (Suministro=27512509).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOLINERA DEL CENTRO S.C.R.L.'
#   - Copiando datos en la hoja 'MOLINERA DEL CENTRO S.C.R.L.' (Suministro=25626420).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Procesadora Delgado S.A.C.'
#   - Copiando datos en la hoja 'Procesadora Delgado S.A.C.' (Suministro=25930653).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: ' Molinera del Peru S.A.'
#   - Copiando datos en la hoja ' Molinera del Peru S.A.' (Suministro=25752319).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'HATUN SOL'
#   - Copiando datos en la hoja 'HATUN SOL' (Suministro=26403831).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'VIMALCA'
#   - Copiando datos en la hoja 'VIMALCA' (Suministro=37826498).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Aguila_25969783'
#   - Copiando datos en la hoja 'Aguila_25969783' (Suministro=25969783).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Procomsac'
#   - Copiando datos en la hoja 'Procomsac' (Suministro=25840224).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'GANDULES'
#   - Copiando datos en la hoja 'GANDULES' (Suministro=25928790).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'LATERCER_27151022'
#   - Copiando datos en la hoja 'LATERCER_27151022' (Suministro=27151022).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Importaciones Savoy E.I.R.L'
#   - Copiando datos en la hoja 'Importaciones Savoy E.I.R.L' (Suministro=35579905).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Gandules_25891804'
#   - Copiando datos en la hoja 'Gandules_25891804' (Suministro=25891804).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Piladora Doña Carmela S.A.C'
#   - Copiando datos en la hoja 'Piladora Doña Carmela S.A.C' (Suministro=27512483).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PROCESADORA_25598101'
#   - Copiando datos en la hoja 'PROCESADORA_25598101' (Suministro=25598101).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Ladrillos_Tayson_37823825 '
#   - Copiando datos en la hoja 'Ladrillos_Tayson_37823825 ' (Suministro=37823825).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'JAYANCA FRUITS'
#   - Copiando datos en la hoja 'JAYANCA FRUITS' (Suministro=26411145).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'AGROIND AIB_25623394'
#   - Copiando datos en la hoja 'AGROIND AIB_25623394' (Suministro=25623394).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'AGROIND AIB_38141848'
#   - Copiando datos en la hoja 'AGROIND AIB_38141848' (Suministro=38141848).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'EMPRESAEDITORAEL COMERCIOS.A'
#   - Copiando datos en la hoja 'EMPRESAEDITORAEL COMERCIOS.A' (Suministro=25597249).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'FRUTOSA_25951288'
#   - Copiando datos en la hoja 'FRUTOSA_25951288' (Suministro=25951288).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Aguila_38168117'
#   - Copiando datos en la hoja 'Aguila_38168117' (Suministro=38168117).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Plant.Sol_26302113'
#   - Copiando datos en la hoja 'Plant.Sol_26302113' (Suministro=26302113).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'DON JULIO_27512456 '
#   - Copiando datos en la hoja 'DON JULIO_27512456 ' (Suministro=27512456).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOLINO CHICLAYO I_27512465'
#   - Copiando datos en la hoja 'MOLINO CHICLAYO I_27512465' (Suministro=27512465).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOLINO CHICLAYO II_36005284'
#   - Copiando datos en la hoja 'MOLINO CHICLAYO II_36005284' (Suministro=36005284).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SANTA ANA_27511403'
#   - Copiando datos en la hoja 'SANTA ANA_27511403' (Suministro=27511403).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'UTP_36000170'
#   - Copiando datos en la hoja 'UTP_36000170' (Suministro=36000170).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'ARROCERA_DEL_PACIFICO'
#   - Copiando datos en la hoja 'ARROCERA_DEL_PACIFICO' (Suministro=27512643).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CASTILLO_25752631 '
#   - No existe el archivo PRN: 'C:\Users\nasca\Desktop\Python Scripts\AUTOMATIZACIÓN PRN a EXCEL_FACTURACIÓN\PRNs a COPIAR\25752631.prn'. Se omite.
#
# Procesando hoja: 'LA_REPUBLICA'
#   - No existe el archivo PRN: 'C:\Users\nasca\Desktop\Python Scripts\AUTOMATIZACIÓN PRN a EXCEL_FACTURACIÓN\PRNs a COPIAR\25596626.prn'. Se omite.
#
# Procesando hoja: 'INVERSIONES_ALVARO'
#   - Copiando datos en la hoja 'INVERSIONES_ALVARO' (Suministro=38978260).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'AGROIND_SAN_FRANCISCO'
#   - Copiando datos en la hoja 'AGROIND_SAN_FRANCISCO' (Suministro=25626206).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PILADORA EL MISTI'
#   - Copiando datos en la hoja 'PILADORA EL MISTI' (Suministro=27536879).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SOL DE OLMOS'
#   - Copiando datos en la hoja 'SOL DE OLMOS' (Suministro=36528203).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PROC_FRUTICOLA '
#   - Copiando datos en la hoja 'PROC_FRUTICOLA ' (Suministro=25623400).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'COMERCIALIZADORA INBC'
#   - Copiando datos en la hoja 'COMERCIALIZADORA INBC' (Suministro=25930662).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CEREALES LAMBAYEQUE S.R.L.'
#   - Copiando datos en la hoja 'CEREALES LAMBAYEQUE S.R.L.' (Suministro=25645533).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: '39197098 SOL DE OLMOS'
#   - Copiando datos en la hoja '39197098 SOL DE OLMOS' (Suministro=39197098).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOLINO EL CHAMESINO S.A.C.'
#   - Copiando datos en la hoja 'MOLINO EL CHAMESINO S.A.C.' (Suministro=25991775).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CELESTIAL'
#   - Copiando datos en la hoja 'CELESTIAL' (Suministro=38530390).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Azucarera-Del-Norte'
#   - Copiando datos en la hoja 'Azucarera-Del-Norte' (Suministro=25648992).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Samamé Chuque_35519442'
#   - Copiando datos en la hoja 'Samamé Chuque_35519442' (Suministro=35519442).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SARITA COLONIA_27512680'
#   - Copiando datos en la hoja 'SARITA COLONIA_27512680' (Suministro=27512680).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PROSERLA'
#   - Copiando datos en la hoja 'PROSERLA' (Suministro=25762431).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOLINOS SAN JORGE_27512492'
#   - Copiando datos en la hoja 'MOLINOS SAN JORGE_27512492' (Suministro=27512492).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'ALLUS_36717837'
#   - Copiando datos en la hoja 'ALLUS_36717837' (Suministro=36717837).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SERV GRANO I'
#   - Copiando datos en la hoja 'SERV GRANO I' (Suministro=27512330).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SERV GRANO II'
#   - Copiando datos en la hoja 'SERV GRANO II' (Suministro=37883556).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'REDIGAL_25859997'
#   - Copiando datos en la hoja 'REDIGAL_25859997' (Suministro=25859997).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SANFABRI'
#   - Copiando datos en la hoja 'SANFABRI' (Suministro=27512474).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'GYB MOLINOS'
#   - Copiando datos en la hoja 'GYB MOLINOS' (Suministro=26371200).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Agroindustrias BETA_38550858'
#   - Copiando datos en la hoja 'Agroindustrias BETA_38550858' (Suministro=38550858).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CAIBETA1'
#   - Copiando datos en la hoja 'CAIBETA1' (Suministro=25947795).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CAIBETA2'
#   - Copiando datos en la hoja 'CAIBETA2' (Suministro=35470065).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CAIBETA3'
#   - Copiando datos en la hoja 'CAIBETA3' (Suministro=36450432).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MolinoSanFernando_38797659'
#   - Copiando datos en la hoja 'MolinoSanFernando_38797659' (Suministro=38797659).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Naya_Peru_27512705'
#   - Copiando datos en la hoja 'Naya_Peru_27512705' (Suministro=27512705).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'AGROPIMA '
#   - Copiando datos en la hoja 'AGROPIMA ' (Suministro=40006063).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'GSP TRUJILLO SAC'
#   - Copiando datos en la hoja 'GSP TRUJILLO SAC' (Suministro=39756374).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'AGRIC_MEZCU'
#   - Copiando datos en la hoja 'AGRIC_MEZCU' (Suministro=36460644).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SanMateo'
#   - Copiando datos en la hoja 'SanMateo' (Suministro=25797651).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'INVER_NUNTON'
#   - Copiando datos en la hoja 'INVER_NUNTON' (Suministro=37118710).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Cerro_Negro_39195146 '
#   - Copiando datos en la hoja 'Cerro_Negro_39195146 ' (Suministro=39195146).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'ASTORAYME_36354131'
#   - Copiando datos en la hoja 'ASTORAYME_36354131' (Suministro=36354131).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Reydinor_39329526'
#   - Copiando datos en la hoja 'Reydinor_39329526' (Suministro=39329526).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'EL LIRIO'
#   - Copiando datos en la hoja 'EL LIRIO' (Suministro=25744943).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PILADORA SOL DE ORO_25869492'
#   - Copiando datos en la hoja 'PILADORA SOL DE ORO_25869492' (Suministro=25869492).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CERAMICOS SUNNY BRIKS_39658954'
#   - Copiando datos en la hoja 'CERAMICOS SUNNY BRIKS_39658954' (Suministro=39658954).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'NOROESTE_25595422'
#   - Copiando datos en la hoja 'NOROESTE_25595422' (Suministro=25595422).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'ASTOLINGON_36000789'
#   - Copiando datos en la hoja 'ASTOLINGON_36000789' (Suministro=36000789).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'GALVEZ ASURZA_25983405'
#   - Copiando datos en la hoja 'GALVEZ ASURZA_25983405' (Suministro=25983405).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'QUICORNAC_25733350'
#   - Copiando datos en la hoja 'QUICORNAC_25733350' (Suministro=25733350).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'AGROINDCAYALTI_25853385'
#   - Copiando datos en la hoja 'AGROINDCAYALTI_25853385' (Suministro=25853385).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CERAMICOS_GALCA'
#   - Copiando datos en la hoja 'CERAMICOS_GALCA' (Suministro=38578090).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'CAUTIVO'
#   - Copiando datos en la hoja 'CAUTIVO' (Suministro=35683298).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'TROPICAL_FARM'
#   - Copiando datos en la hoja 'TROPICAL_FARM' (Suministro=35950177).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'San Cristobal'
#   - Copiando datos en la hoja 'San Cristobal' (Suministro=25824614).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PesqMarmar'
#   - Copiando datos en la hoja 'PesqMarmar' (Suministro=38903626).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Piladora Nuevo Horizonte S.A.C'
#   - Copiando datos en la hoja 'Piladora Nuevo Horizonte S.A.C' (Suministro=37123747).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'HuertoGenesis_26433035'
#   - Copiando datos en la hoja 'HuertoGenesis_26433035' (Suministro=26433035).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Mall Aventura_38865561'
#   - Copiando datos en la hoja 'Mall Aventura_38865561' (Suministro=38865561).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Mall Aventura_38895275'
#   - Copiando datos en la hoja 'Mall Aventura_38895275' (Suministro=38895275).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Complejo_Beta_38898992'
#   - Copiando datos en la hoja 'Complejo_Beta_38898992' (Suministro=38898992).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Complejo_Beta_38976319'
#   - Copiando datos en la hoja 'Complejo_Beta_38976319' (Suministro=38976319).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Molino_Las_Delicias_27512581'
#   - Copiando datos en la hoja 'Molino_Las_Delicias_27512581' (Suministro=27512581).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Consorcio_Hoteler_Walu 39195880'
#   - Copiando datos en la hoja 'Consorcio_Hoteler_Walu 39195880' (Suministro=39195880).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'San_Martin_Traing_39166805'
#   - Copiando datos en la hoja 'San_Martin_Traing_39166805' (Suministro=39166805).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'GRANOVERDE_39227203'
#   - Copiando datos en la hoja 'GRANOVERDE_39227203' (Suministro=39227203).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PERU FRESH_36450441'
#   - Copiando datos en la hoja 'PERU FRESH_36450441' (Suministro=36450441).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'SAN ROQUE S.A._26438621'
#   - Copiando datos en la hoja 'SAN ROQUE S.A._26438621' (Suministro=26438621).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'PILAD_LA_MERCED'
#   - Copiando datos en la hoja 'PILAD_LA_MERCED' (Suministro=26248850).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'ESCALY'
#   - Se esperaban 2880 lecturas, hay 2751. Se omite.
#
# Procesando hoja: 'AGRIC_LATINO_35891595'
#   - Se esperaban 2880 lecturas, hay 2274. Se omite.
#
# Procesando hoja: 'ATLANTICA_36453532'
#   - Copiando datos en la hoja 'ATLANTICA_36453532' (Suministro=36453532).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'INV.MOCCE_26382295'
#   - Se esperaban 2880 lecturas, hay 1696. Se omite.
#
# Procesando hoja: 'Santa_Cruz_Lizaida'
#   - Se esperaban 2880 lecturas, hay 1680. Se omite.
#
# Procesando hoja: 'LadrilloTorreFuerte39401262'
#   - Se esperaban 2880 lecturas, hay 1699. Se omite.
#
# Procesando hoja: 'Broom_Frio_39509005'
#   - Copiando datos en la hoja 'Broom_Frio_39509005' (Suministro=39509005).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'Molino del Agricultor'
#   - Se esperaban 2880 lecturas, hay 1678. Se omite.
#
# Procesando hoja: 'MOLINO'S CRISTO MORADO SAC'
#   - Se esperaban 2880 lecturas, hay 2273. Se omite.
#
# Procesando hoja: 'INDUAMERICA CHICLAYO SAC'
#   - Se esperaban 2880 lecturas, hay 1700. Se omite.
#
# Procesando hoja: 'Hielo Rosymar S.A.C'
#   - Copiando datos en la hoja 'Hielo Rosymar S.A.C' (Suministro=39771890).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'MOL_GRANO_DORADO'
#   - Se esperaban 2880 lecturas, hay 1676. Se omite.
#
# Procesando hoja: 'HERRI_PERU '
#   - Copiando datos en la hoja 'HERRI_PERU ' (Suministro=25985698).
#     * Se copiaron 2880 lecturas en columnas F y G.
#
# Procesando hoja: 'AGRICOLA_BGS'
#   - Se esperaban 2880 lecturas, hay 2732. Se omite.
#
# Procesando hoja: 'MOLINERA RAM'
#   - Se esperaban 2880 lecturas, hay 1697. Se omite.
#
# Procesando hoja: 'INVER_YARABAMBA'
#   - Se esperaban 2880 lecturas, hay 2353. Se omite.
#
# Procesando hoja: 'CECINA_SAC'
#   - Se esperaban 2880 lecturas, hay 2272. Se omite.
#
# Procesando hoja: 'EAI CAYALTI_40041456'
#   - Se esperaban 2880 lecturas, hay 2349. Se omite.
#
# El archivo Excel 'C:\Users\nasca\Desktop\Python Scripts\AUTOMATIZACIÓN PRN a EXCEL_FACTURACIÓN\Libres Ensa_09_2025.xlsm' se ha actualizado.
#
# Resumen de problemas encontrados:
#                            Hoja Suministro                     Problema  \
# 0              Mol_San Fernando   25650749          Lecturas diferentes
# 1            CASTILLO_25752631    25752631  No se encontró 25752631.prn
# 2                  LA_REPUBLICA   25596626  No se encontró 25596626.prn
# 3                        ESCALY   25647298          Lecturas diferentes
# 4         AGRIC_LATINO_35891595   35891595          Lecturas diferentes
# 5            INV.MOCCE_26382295   26382295          Lecturas diferentes
# 6            Santa_Cruz_Lizaida   27512750          Lecturas diferentes
# 7   LadrilloTorreFuerte39401262   39401262          Lecturas diferentes
# 8         Molino del Agricultor   27512714          Lecturas diferentes
# 9    MOLINO'S CRISTO MORADO SAC   25765809          Lecturas diferentes
# 10     INDUAMERICA CHICLAYO SAC   39744687          Lecturas diferentes
# 11             MOL_GRANO_DORADO   39968133          Lecturas diferentes
# 12                 AGRICOLA_BGS   35474725          Lecturas diferentes
# 13                 MOLINERA RAM   25723166          Lecturas diferentes
# 14              INVER_YARABAMBA   40184299          Lecturas diferentes
# 15                   CECINA_SAC   38233627          Lecturas diferentes
# 16         EAI CAYALTI_40041456   40041456          Lecturas diferentes
#
#     LecturasEncontradas  LecturasEsperadas
# 0                 420.0               2880
# 1                   NaN               2880
# 2                   NaN               2880
# 3                2751.0               2880
# 4                2274.0               2880
# 5                1696.0               2880
# 6                1680.0               2880
# 7                1699.0               2880
# 8                1678.0               2880
# 9                2273.0               2880
# 10               1700.0               2880
# 11               1676.0               2880
# 12               2732.0               2880
# 13               1697.0               2880
# 14               2353.0               2880
# 15               2272.0               2880
# 16               2349.0               2880

# %%
a=[1,2,3,4]
for i in a:
    print(a[:-1])
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]
